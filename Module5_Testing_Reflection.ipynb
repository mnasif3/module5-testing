# %% [markdown]
# Module 5 Programming Assignment – Testing

# %% [markdown]
# The unit tests were executed using Python’s unittest framework in VS Code.
# Two tests were run: one for the add function and one for the subtract function.
# Both tests passed successfully, which means the functions returned the expected results.
# The output confirms that the code behaves correctly and meets the requirements defined in the tests.
# If a test had failed, it would indicate a logic error in the function being tested.
